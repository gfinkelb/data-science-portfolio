# %% [markdown]
# izil-atij-tuma-syza Greg Finkelberg

# %% [markdown]
# Question 1. Rearrange the lines of code below to produce a program fragment that reads user input and prints whether a time (such as 9 am) is in the morning, afternoon, or evening. Prompt the user for the hour before the suffix.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 2. In this activity, you will trace through an example of a misaligned else statement. The code is supposed to determine whether a time (such as 9 am) is in the morning, afternoon, or evening. For each input set, click on the conditions of the if statement that are tested and then on the statement that is executed (which may be another if statement). Be sure to trace what actually happens, even though the result will not be correct.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 3. Fix the code from the preceding problem so that the correct greeting is produced. Be sure to properly align the if and else statements.
#
# ![image.png](attachment:image.png)

# %%
#Question 3 code.

time = "morning"
hour = int(input("Hour: "))

suffix = input("Suffix: ")
if suffix == "pm" :
    if hour < 6 :
        time = "afternoon"
    else:
        time = "evening"
print("Good", time)
# Out:
# Hour: 9
# Suffix: am
# Good morning

# %% [markdown]
# Question 4. Complete this program that reads the times for two events, such as 3 pm and 11 am. Determine whether the first event occurs before the second event, at the same time, or after the second event. Print "Before", "Same", or "After".
#
# ![image.png](attachment:image.png)

# %%
#Question 4 code

time1 = int(input("First time: "))
suffix1 = input("suffix: ")
time2 = int(input("Second time: "))
suffix2 = input("suffix: ")

if suffix1 == suffix2:
    if time1 < time2:
        print("Before")
    else: 
        if time1 > time2:
            print("After")
        else:
            print("Same")
else:
    if suffix1 == "am":
        print("Before")
    else:
        print("After")
# Out:
# First time: 9
# suffix: am
# Second time: 10
# suffix: pm
# Before

# %% [markdown]
# Question 5. Simplify the following logical conditions, assuming that n contains an integer value and b contains a Boolean value.
#
# ![image.png](attachment:image.png)
