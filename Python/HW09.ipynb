# %% [markdown]
# uleg-gyje-yzad-jyve Greg Finkelberg

# %% [markdown]
# Question 1. Assume scores is a list of integers. Fill in the following code snippets.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 2. Complete the following program that multiplies each element of a list by five.

# %%
#Question 2 code
values = [2, 3, 5, 7, 11]
for i in range(len(values)):
    values[i] *= 5
    
for element in values :
    print(element)
# Out:
# 10
# 15
# 25
# 35
# 55

# %% [markdown]
# Question 3. Complete the following program that removes the maximum value from a given list.

# %%
#Question 3 code
values = [17, 25, 5, 30, 100, 96, 48, 5, 14, 30]
max_value = max(values)
values.remove(max_value)
print(values)
# Out:
# [17, 25, 5, 30, 96, 48, 5, 14, 30]

# %% [markdown]
# Question 4. Complete the following program that creates a duplicate version of a list but with the elements stored in reverse order from the original.

# %%
#Question 4 code
origValues = [17, 25, 5, 30, 100, 96, 48, 5, 14, 30]
newValues = []
newValues = origValues[::-1]
print(newValues)
# Out:
# [30, 14, 5, 48, 96, 100, 30, 5, 25, 17]

# %% [markdown]
# Question 5. Implement the fill function that fills all elements of a list with a given value. For example, the call fill(scores, 10) should fill all elements of the list scores with the value 10.
#
# ![image.png](attachment:image.png)
