# %% [markdown]
# udyq-ujox-obyx-ovif Greg Finkelberg

# %% [markdown]
# Question 1. Trace through the following code:
#
# ![image.png](attachment:image.png)

# %%
#Question 1 code
for n in range(2, 4) :   
    p = 1   
    for i in range(1, 4) :
        p = p * n      
        print("%2d" % p, end="")   
    print()
print()
# Out:
#  2 4 8
#  3 927

# %% [markdown]
# Question 2. Rearrange the following lines of code so that they print the following shape. Not all lines are useful.
#
# ![image.png](attachment:image.png)

# %%
#Question 2 code

for i in range(0, 3) :
    for j in range(0, 5) :
        print("[]", end="")
    print()
# Out:
# [][][][][]
# [][][][][]
# [][][][][]

# %% [markdown]
# Question 3. Complete the following program to make a table of integers from 0 to n (inclusive) and their square roots. The table should be formatted like this one and display the square roots to the same number of decimal places:
#
#  n | Root of n
# ----|----------
#   0 |  0.000000
#   1 |  1.000000
#   2 |  1.414214

# %%
#Question 3 code

from math import sqrt

n = int(input("Enter a positive integer: "))

print("  n | Root of n")
print("----|----------")
   
for i in range(n + 1):
    square_root = sqrt(i)
    print("{:3d} | {:<.6f}".format(i, square_root))
# Out:
# Enter a positive integer: 10
#   n | Root of n
# ----|----------
#   0 | 0.000000
#   1 | 1.000000
#   2 | 1.414214
#   3 | 1.732051
#   4 | 2.000000
#   5 | 2.236068
#   6 | 2.449490
#   7 | 2.645751
#   8 | 2.828427
#   9 | 3.000000
#  10 | 3.162278

# %% [markdown]
# Question 4. Complete the following program that displays:
#
# by filling in the correct conditions of the two while loops.
#
# ![image.png](attachment:image.png)

# %%
#Question 4 code
j = 4
while j > 0:
    k = 1
    while k <=j:
        print("#", end="")
        k = k + 1
    print()
    j = j - 1
# Out:
# ####
# ###
# ##
# #

# %% [markdown]
# Question 5. Complete this program that reads an integer n and prints the following diamond pattern with 2 * n - 1 asterisks at its widest point. This is the pattern when n is 3:

# %%
#Question 5 code

n = int(input("Enter value of n: "))

# Draw top half and middle of the diamond
for leftStars in range(n):
    for column in range(2 * n - 1):
        firstStar = n - 1 - leftStars
        lastStar = n - 1 + leftStars
        if column < firstStar or column > lastStar:
            print("-", end="")
        else:
            print("*", end="")
    print()

# Draw bottom half of the diamond
for leftStars in range(n - 2, -1, -1):
    for column in range(2 * n - 1):
        firstStar = n - 1 - leftStars
        lastStar = n - 1 + leftStars
        if column < firstStar or column > lastStar:
            print("-", end="")
        else:
            print("*", end="")
    print()
# Out:
# Enter value of n: 3
# --*--
# -***-
# *****
# -***-
# --*--
