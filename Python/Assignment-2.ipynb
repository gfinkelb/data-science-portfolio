# %% [markdown]
# ucuh-caqy-lyfi-sugi Greg Finkelberg

# %% [markdown]
# Question 1. What happens when the following code is executed?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 2. Rearrange the following lines to produce a program snippet that computes and prints the number of coins in a piggybank, given the number of nickels, dimes, and quarters. Be sure to place the comments so that they truthfully describe the steps within the program.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 3. Complete this program that computes the area and perimeter of a rectangle with given width and height. If a rectangle has width w and height h, then the area is wh, and the perimeter is 2(w + h).
#
# ![image.png](attachment:image.png)

# %%
# Question 3 code
width = 10
height = 20 

area = width * height 
perimeter = 2*(width + height)

print("Area: ", area)
print("Perimeter: ", perimeter)
# Out:
# Area:  200
# Perimeter:  60

# %% [markdown]
# Question 4. In order to paint a wall that has a number of windows, we want to know its area. Each window has a size of 2 ft by 3 ft. Write a program that reads the width and height of the wall and the number of windows, using the prompts
#
# Wall width:
# Wall height:
# Number of windows:
#
# Then print the area. The width and height of the wall should be entered as a floating-point value and the number of windows as an integer.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# Question 4 code
# Get inputs
wall_width = float(input("Wall width: "))
wall_height = float(input("Wall height: "))
num_windows = int(input("Number of windows: "))

# Calculate wall area
wall_area = wall_width * wall_height

# Calculate total window area
window_area = 2 * 3 * num_windows

# Subtract window area from wall area
net_wall_area = wall_area - window_area
     
print("Area:", net_wall_area)
# Out:
# Wall width: 30
# Wall height: 30
# Number of windows: 3
# Area: 882.0

# %% [markdown]
# Question 5. Give the value for each of the expressions below assuming the following definitions:
#
# greeting = "Hello"
# location = "World"
#
# In your anwers to this problem, be sure to put double quotation marks around any string values.
#
# ![image.png](attachment:image.png)
